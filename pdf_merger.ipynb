# %%
import os 
import PyPDF2
from PyPDF2 import PdfReader , PdfWriter, PdfMerger

# %%
PDFS_TO_MERGE = [
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 009_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 014_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 015_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 021_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 031_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 036_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 037_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 043_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 048_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 056_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Documentos/ViT/2024_OCR/NEW_DATA_PDF/Encuesta 061_Grigori Sidorov_0001.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numero-7.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-1.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-2.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-3.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-4.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-5.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-6.pdf",
    "/home/ralvarez22/Descargas/OneDrive_1_13-8-2024/Numeros-8.pdf"
]

OUT_PDF_MERGED = "/home/ralvarez22/Documentos/trocr_hand/trocr_llm/pdfs/cursive_full_data.pdf"

# %%
pdfWriter = PyPDF2.PdfWriter()

# %%
for filename in PDFS_TO_MERGE:
    pdfFileObj = open(filename, 'rb')
    pdfReader = PyPDF2.PdfReader(pdfFileObj)
    for pageNum in range(0, len(pdfReader.pages)):
        pageObj = pdfReader.pages[pageNum]
        pdfWriter.add_page(pageObj)

# %%
pdfOutput = open(OUT_PDF_MERGED, 'wb') 

# Writing the output file using the pdfWriter function.
pdfWriter.write(pdfOutput)
pdfOutput.close()
